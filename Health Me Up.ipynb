# %%
from tkinter import *
from tkinter import ttk
from tkinter import messagebox
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

root=Tk()
root.title("Health Me Up!")
root.configure(background='#FFE4C4')

#Function to predict the outcome
def predict():
    name=ent1.get()
    heightin=float(ent2.get())
    weight=int(ent3.get())
    gender=int(g.get())
    
    #Fetching the Data
    data=pd.read_csv("BMI_Data.csv")
    data_dataframe=pd.DataFrame(data)
    
    # Spliting-out validation dataset
    array = data_dataframe.values
    X = array[:,0:4]
    Y = array[:,4]
    validation_size = 0.20
    seed = 7
    X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=seed)
   
    # Test options and evaluation metric
    seed = 7
    scoring = 'accuracy'
    
    # Prediciting DataSet
    height=0.0254*heightin
    bmi=weight/(height**2)
    P=[[gender,weight,height,bmi]]
    
    # Decision Tree Model
    clf = DecisionTreeClassifier()
    clf = clf.fit(X_validation,Y_validation)
    result=str(clf.predict(P))
    messagebox.showinfo (title='Result', message="Hello " '%s \n As per the calculations, \n You are %s' %(name,result))
    
#Adding the logo
imagelogo=PhotoImage(file='153157624430073963.png')
logo = Label(root, image=imagelogo,background='#FFE4C4')
logo.place(x=75, y=-20)
lable1 = Label(root, text="HEALTH ME UP!",background='#FFE4C4',fg="#D2691E",font = "Arial 100 bold").place(x=330, y=30)

#Adding image and text
imageex=PhotoImage(file='asdfgh.png')
imgg = Label(root, image=imageex,background='#FFE4C4',height=600,width=800)
imgg.place(x=850, y=160)
lable1 = Label(root, text="Health is the ability of a biological \nsystem to acquire,convert, allocate, distribute,\n and utilize energy with maximum efficiency.\n The World Health Organization (WHO) \n defined human health as a state of \n complete physical, mental and social well-being \n and not merely the absence of disease or infirmity.",background='#FFE4C4',fg="#D2691E",font = "Arial 15 bold",anchor="w", borderwidth=2,relief="solid",highlightcolor="#D2691E").place(x=20, y=350)

#Inserting the labels
lable1 = Label(root, text="Name:",background='#FFE4C4',font = "Arial 35 bold",fg="#D2691E").place(x=550, y=250)
lable2 = Label(root, text="Gender:",background='#FFE4C4',font = "Arial 35 bold",fg="#D2691E").place(x=545, y=350)
lable3 = Label(root, text="Height:",background='#FFE4C4',font = "Arial 35 bold",fg="#D2691E").place(x=550, y=450)
lablex1 = Label(root, text="(in inches)",background='#FFE4C4',font = "Arial 15 ",fg="#D2691E").place(x=550, y=508)
lable4 = Label(root, text="Weight:",background='#FFE4C4',font = "Arial 35 bold",fg="#D2691E").place(x=550, y=570)
lableex2 = Label(root, text="(in kgs)",background='#FFE4C4',font = "Arial 15",fg="#D2691E").place(x=550, y=630)

#Inputting the data
large_font = ('Verdana',15)
entry1Var = StringVar(value='Large Font!')
ent1 = Entry(root,font=large_font)
ent1.place(x=750, y=270)
ent2 = Entry(root,font=large_font)
ent2.place(x=750, y=470)
ent3 = Entry(root,font=large_font)
ent3.place(x=750, y=590)

g=IntVar()
radio1=Radiobutton(root,text="Male",variable=g,value=0,background='#FFE4C4',font = "Arial 15",fg="#D2691E")
radio1.place(x=750, y=365)
radio2 = Radiobutton(root, text="Female", variable=g, value=1,background='#FFE4C4',font = "Arial 15",fg="#D2691E")
radio2.place(x=850, y=365)

button1 = Button(root, text="Predict",command=predict,width=10,background='#A0522D',font = "Arial 15",fg="#FDF5E6")
button1.place(x=700, y=700)
button2 = Button(root, text='Quit', command=root.destroy,width=10,background='#A0522D',font = "Arial 15",fg="#FDF5E6")
button2.place(x=900,y=700)



root.mainloop()
